# %% [markdown]
# <a href="https://colab.research.google.com/github/Nunrod1201/Python/blob/main/Copy_of_3_Text.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **This** i
#
# ```
# # This is formatted as code
# ```
# for item in list:
# print(item)

# %% [markdown]
# [Google search](https://www.google.com)

# %% [markdown]
# Hello

# %% [markdown]
# 1.   first
# 2.   second

# %% [markdown]
# $a*x^2+bx +c = 0$

# %% [markdown]
# $$X1 = \frac{-b + \sqrt{b^2 - 4ac}}{2a}$$

# %% [markdown]
# ![Screenshot 2567-06-14 at 16.54.46.png](data:image/png;base64,...)
